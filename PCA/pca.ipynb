# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.decomposition import PCA
from sklearn import datasets

# %%
dataset = datasets.load_iris()

# %%
X = dataset['data']
y = dataset['target']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state = 64)

# %%
pca = PCA(n_components=3)
#we are reducing from 4 features to 3

# %%
X_train
# Out:
# array([[5.7, 2.8, 4.1, 1.3],
#        [4.9, 2.4, 3.3, 1. ],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.9, 3.2, 4.8, 1.8],
#        [5.5, 2.3, 4. , 1.3],
#        [5. , 3.3, 1.4, 0.2],
#        [6. , 2.9, 4.5, 1.5],
#        [6.5, 3. , 5.2, 2. ],
#        [4.6, 3.1, 1.5, 0.2],
#        [6.3, 3.3, 4.7, 1.6],
#        [6.1, 2.6, 5.6, 1.4],
#        [6.4, 2.9, 4.3, 1.3],
#        [4.6, 3.6, 1. , 0.2],
#        [6.3, 2.5, 4.9, 1.5],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.4, 3.7, 1.5, 0.2],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 4.2, 1.5],
#        [7.2, 3.6, 6.1, 2.5],
#        [5.8, 2.6, 4. , 1.2],
#        [6.3, 2.3, 4.4, 1.3],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.8, 2.8, 5.1, 2.4],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.7, 2.9, 4.2, 1.3],
#        [7.7, 3.8, 6.7, 2.2],
#        [6.7, 3.1, 4.7, 1.5],
#        [4.9, 3.1, 1.5, 0.1],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.1, 2.8, 4.7, 1.2],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.7, 3.1, 4.4, 1.4],
#        [4.8, 3. , 1.4, 0.3],
#        [7.3, 2.9, 6.3, 1.8],
#        [7.4, 2.8, 6.1, 1.9],
#        [6.3, 2.7, 4.9, 1.8],
#        [4.9, 3. , 1.4, 0.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.4, 2.8, 5.6, 2.1],
#        [4.7, 3.2, 1.3, 0.2],
#        [7.7, 3. , 6.1, 2.3],
#        [5.5, 2.4, 3.8, 1.1],
#        [7.1, 3. , 5.9, 2.1],
#        [5.9, 3. , 5.1, 1.8],
#        [4.8, 3.4, 1.6, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [5.1, 2.5, 3. , 1.1],
#        [4.8, 3.4, 1.9, 0.2],
#        [6.5, 3. , 5.8, 2.2],
#        [6.9, 3.1, 5.1, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [5.5, 2.5, 4. , 1.3],
#        [6.1, 3. , 4.9, 1.8],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.7, 3. , 5. , 1.7],
#        [5.1, 3.4, 1.5, 0.2],
#        [4.9, 2.5, 4.5, 1.7],
#        [6.8, 3. , 5.5, 2.1],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.7, 2.8, 4.5, 1.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [6.4, 2.7, 5.3, 1.9],
#        [5.7, 4.4, 1.5, 0.4],
#        [6.3, 2.5, 5. , 1.9],
#        [4.5, 2.3, 1.3, 0.3],
#        [5. , 2. , 3.5, 1. ],
#        [5.1, 3.7, 1.5, 0.4],
#        [6.4, 2.8, 5.6, 2.2],
#        [5.1, 3.8, 1.6, 0.2],
#        [5.7, 3. , 4.2, 1.2],
#        [6.7, 3.1, 5.6, 2.4],
#        [5.1, 3.5, 1.4, 0.2],
#        [6.7, 3.3, 5.7, 2.1],
#        [6.1, 2.8, 4. , 1.3],
#        [4.4, 2.9, 1.4, 0.2],
#        [7.9, 3.8, 6.4, 2. ],
#        [5.2, 3.5, 1.5, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5. , 3.2, 1.2, 0.2],
#        [6.8, 3.2, 5.9, 2.3],
#        [5. , 3.4, 1.6, 0.4],
#        [6.6, 3. , 4.4, 1.4],
#        [5.7, 3.8, 1.7, 0.3],
#        [6.2, 2.8, 4.8, 1.8],
#        [4.4, 3. , 1.3, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [5.7, 2.6, 3.5, 1. ],
#        [5. , 2.3, 3.3, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [5.2, 2.7, 3.9, 1.4],
#        [6. , 2.2, 4. , 1. ],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.8, 4. , 1.2, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.1, 3. , 4.6, 1.4],
#        [7.2, 3.2, 6. , 1.8],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.6, 3. , 4.5, 1.5],
#        [5.5, 3.5, 1.3, 0.2],
#        [5.7, 2.5, 5. , 2. ],
#        [5.4, 3.9, 1.3, 0.4],
#        [4.9, 3.1, 1.5, 0.2],
#        [6.3, 3.4, 5.6, 2.4],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.3, 3.7, 1.5, 0.2],
#        [6. , 3.4, 4.5, 1.6],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.5, 2.8, 4.6, 1.5],
#        [6. , 2.2, 5. , 1.5]])

# %%
X_train = pca.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.31484141, -0.33884266,  0.03876432],
#        [-0.7359588 , -0.99066939,  0.06263748],
#        [-2.82323511, -0.20255152,  0.1008245 ],
#        [ 1.13231242, -0.060259  ,  0.47935433],
#        [ 0.19741245, -0.82734759, -0.13910201],
#        [-2.68556847,  0.1235874 , -0.08920642],
#        [ 0.82979244, -0.15501106,  0.05631813],
#        [ 1.78139009,  0.08334805,  0.13589831],
#        [-2.72935373, -0.29486484,  0.05325921],
#        [ 1.11316241,  0.2965641 ,  0.17590564],
#        [ 1.79750808, -0.49311426, -0.11422868],
#        [ 0.73322858,  0.14221671, -0.31609148],
#        [-3.19876066,  0.16670178,  0.29108565],
#        [ 1.31474329, -0.33662591, -0.32016354],
#        [-0.15810553, -0.24363949,  0.10561185],
#        [ 0.96037906, -0.56159906, -0.47567061],
#        [-2.48695554,  0.6612303 , -0.09375021],
#        [ 1.91707848,  0.14532114,  0.73064681],
#        [ 0.52814073, -0.09252589,  0.14456129],
#        [ 2.9360643 ,  0.79385311,  0.40404264],
#        [ 0.24655192, -0.40468357, -0.20189319],
#        [ 0.83180373, -0.3924144 , -0.59289878],
#        [ 1.48419128,  0.49437694, -0.34302594],
#        [ 1.59922238, -0.51867502,  0.64862874],
#        [-0.17451773, -0.68082849, -0.26701228],
#        [ 0.39225525, -0.27924733,  0.10772524],
#        [ 3.50910438,  1.18182631,  0.12030828],
#        [ 1.23994584,  0.40200263, -0.24027457],
#        [-2.65551294, -0.10006381, -0.18432128],
#        [ 2.33822579, -0.25516008, -0.31809728],
#        [ 3.52027307,  0.43660822, -0.56504272],
#        [ 0.93904298, -0.17964945, -0.19670278],
#        [ 1.42953354, -0.55881637,  0.33356574],
#        [ 0.94741848,  0.45824222, -0.32372799],
#        [-2.69823284, -0.23653047, -0.08848874],
#        [ 2.95237938,  0.34213914, -0.40399681],
#        [ 2.86137756,  0.35428635, -0.49436908],
#        [ 1.40502931, -0.20620504, -0.0495574 ],
#        [-2.69734226, -0.16682173, -0.20192223],
#        [ 1.4613372 , -0.14148093, -0.12397859],
#        [ 2.1395575 , -0.20370533,  0.17559685],
#        [-2.87240762, -0.12364637,  0.02805318],
#        [ 3.09667341,  0.66518307, -0.35862347],
#        [-0.05328559, -0.70435008, -0.20495449],
#        [ 2.63535852,  0.33694937, -0.11029803],
#        [ 1.40572281, -0.26124465,  0.39492157],
#        [-2.59545723,  0.04173144,  0.11459933],
#        [-2.71026979,  0.35145038,  0.08558289],
#        [-2.75209911,  0.28469246,  0.06798195],
#        [-0.89260068, -0.74770837,  0.0160201 ],
#        [-2.33851439, -0.00734555,  0.14669278],
#        [ 2.36644481, -0.02913112,  0.30280517],
#        [ 1.94016268,  0.40435819,  0.08924951],
#        [ 1.96716388,  0.04859625,  0.06527181],
#        [ 0.18094491, -0.67543894, -0.0225758 ],
#        [ 1.30737779, -0.10343436,  0.24937893],
#        [ 1.98809506, -0.16880937,  0.14185353],
#        [ 1.5762915 ,  0.26264613, -0.16372427],
#        [-2.57167953,  0.24572888, -0.08231901],
#        [ 0.53267044, -1.16116119,  0.60879423],
#        [ 2.18334276,  0.21474691,  0.03313122],
#        [ 0.66027838,  0.01712442, -0.19194447],
#        [ 0.65743186, -0.40427864,  0.08155559],
#        [-2.98183293, -0.31128482,  0.21427369],
#        [ 1.81967939, -0.21625748, -0.01747966],
#        [-2.36399759,  1.36622385,  0.23059096],
#        [ 1.542729  , -0.38163529, -0.10402581],
#        [-2.83566935, -0.93949021, -0.32080777],
#        [-0.49525338, -1.26465855, -0.21109281],
#        [-2.5252118 ,  0.45926667,  0.19519026],
#        [ 2.17514202, -0.21086792,  0.22695683],
#        [-2.51896701,  0.53318719,  0.16143123],
#        [ 0.34843695, -0.1961304 ,  0.11462837],
#        [ 2.33103506,  0.19030831,  0.31824558],
#        [-2.66556092,  0.3380422 , -0.03475372],
#        [ 2.29346156,  0.34734575,  0.29138967],
#        [ 0.37509421, -0.07229907, -0.22022752],
#        [-2.871484  , -0.5555068 ,  0.0501822 ],
#        [ 3.25394271,  1.37032078, -0.13865213],
#        [-2.5434382 ,  0.38422935, -0.08612941],
#        [-2.38840271,  0.21412768,  0.25415533],
#        [-2.84862993,  0.08035107, -0.16886516],
#        [ 2.58063471,  0.28689439,  0.29516865],
#        [-2.45133798,  0.15249854,  0.09317227],
#        [ 0.91917715,  0.31974174, -0.31991759],
#        [-2.17888425,  0.88494249, -0.14895201],
#        [ 1.27467283, -0.17643787,  0.0600814 ],
#        [-2.96536539, -0.46319347,  0.09774748],
#        [-2.76940188, -0.22220528, -0.1912087 ],
#        [-0.28933029, -0.37110955, -0.29602872],
#        [-0.69124992, -1.00407757, -0.05769913],
#        [ 0.15267054, -0.31237025, -0.1543279 ],
#        [ 0.00498896, -0.70197232,  0.32083309],
#        [ 0.28126818, -0.5690834 , -0.66181257],
#        [-2.19085513,  0.46978501,  0.29624463],
#        [-2.80411814, -0.05780546,  0.26871068],
#        [-2.62269928,  1.18835487, -0.19934837],
#        [-2.48957193, -0.13699358, -0.2426001 ],
#        [-2.78232942,  0.29606683,  0.09629642],
#        [ 1.00197825, -0.11802031, -0.03571972],
#        [-2.62842536,  0.84711791,  0.21208924],
#        [ 1.67927493,  0.25161571,  0.2417267 ],
#        [ 0.90809686, -0.02570699,  0.01184557],
#        [ 2.63426012,  0.55653296, -0.19922744],
#        [-2.29095899,  0.40064933, -0.24714389],
#        [ 0.67565825, -0.32924133,  0.36287526],
#        [-2.60530811,  0.60458579, -0.29374556],
#        [ 1.3594629 , -0.76407477,  0.3197752 ],
#        [-2.60354927,  0.83153176,  0.10410032],
#        [-2.61992842, -0.1072264 , -0.13296131],
#        [ 2.16043333,  0.1679867 ,  0.74132892],
#        [ 3.8147894 ,  0.23049379, -0.50609336],
#        [ 1.18525507, -0.14962151,  0.30075462],
#        [ 2.44581458,  0.38215853,  0.21169951],
#        [-2.39108518,  0.41904213, -0.16581957],
#        [-2.52343064,  0.59868416, -0.0316767 ],
#        [ 0.8242081 ,  0.21759798,  0.39899363],
#        [ 0.95099154,  0.32303651, -0.01718658],
#        [ 1.10604934,  0.06540635, -0.30161468],
#        [ 1.31566692, -0.76848634, -0.29803452]])

# %%
pca.components_
# Out:
# array([[ 0.36475104, -0.08233773,  0.85647613,  0.35584522],
#        [ 0.62546148,  0.75954328, -0.16358997, -0.07162595],
#        [-0.62073505,  0.58263104,  0.10697816,  0.51359978]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.92439022, 0.05464073, 0.01593832])
